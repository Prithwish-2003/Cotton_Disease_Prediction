# %%
from collections import namedtuple
import os

# %%
# %pwd
# Out:
# 'd:\\Computer_Vision\\pouravi_computer_vision_project\\cotton_disease_classification\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Computer_Vision\\pouravi_computer_vision_project\\cotton_disease_classification'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassifier.constants import *

# %%
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=Path(config.source_URL),
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config


    # def download_file(self)-> str:
    #     '''
    #     Fetch data from the url
    #     '''

    #     try: 
    #         dataset_url = self.config.source_URL
    #         zip_download_dir = self.config.local_data_file
    #         os.makedirs("artifacts/data_ingestion", exist_ok=True)
    #         logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

    #         file_id = dataset_url.split("/")[-2]
    #         prefix = 'https://drive.google.com/uc?/export=download&id='
    #         gdown.download(prefix+file_id,zip_download_dir)

    #         logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

    #     except Exception as e:
    #         raise e
     
 
        
    def _get_updated_list_of_files(self,list_of_files):
        list = []
        for i in list_of_files:
                dir , file = os.path.split(i)
                if "test data comp files" not in dir :
                        list.append(i)
                else :
                        continue
                
        return list
    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            list = zip_ref.namelist()
            list =self._get_updated_list_of_files(list)
            for i in list :
                target_filepath = os.path.join(unzip_path, i)
                if not os.path.exists(target_filepath):  
                        zip_ref.extract(i,unzip_path)

# %%
from pathlib import Path
with zipfile.ZipFile(Path(r'data/drive-download-20240504T060834Z-001.zip'), 'r') as zip_ref:
            list = zip_ref.namelist()

# %%
list
# Out:
# ['test/test data comp files/d (378)_compressed.jpg',
#  'test/test data comp files/dd (41)_compressed.jpg',
#  'test/test data comp files/dis_leaf (322)_compressed.jpg',
#  'test/fresh cotton plant/dsd (632).jpg',
#  'test/diseased cotton leaf/dis_leaf (248).jpg',
#  'test/test data comp files/d (341)_compressed.jpg',
#  'test/test data comp files/dd (513)_compressed.jpg',
#  'test/fresh cotton leaf/d (396).jpg',
#  'test/test data comp files/d (396)_compressed.jpg',
#  'test/test data comp files/d (366)_compressed.jpg',
#  'test/test data comp files/dsd (223)_compressed.jpg',
#  'test/test data comp files/d (384)_compressed.jpg',
#  'test/test data comp files/dd (706)_compressed.jpg',
#  'test/test data comp files/dd (367)_compressed.jpg',
#  'test/fresh cotton leaf/d (341).jpg',
#  'test/fresh cotton plant/dsd (600).jpg',
#  'test/test data comp files/dd (328)_compressed.jpg',
#  'test/diseased cotton leaf/dis_leaf (124).jpg',
#  'test/test data comp files/dsd (228)_compressed.jpg',
#  'test/test data comp files/dsd (405)_compressed.jpg',
#  'test/test data comp files/dsd (600)_compressed.jpg',
#  'test/fresh cotton leaf/d (366).jpg',
#  'test/test data comp files/dis_leaf (124)_compressed.jpg',
#  'test/fresh cotton plant/dsd (223).jpg',
#  'test/fresh cotton plant/dsd (405).jpg',
#  'val/diseased cotton leaf/dis_leaf (206)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (224)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (193)_iaip.jpg',
#  'test/test data comp files/dis_leaf (248)_compressed.jpg',
#  'val/diseased cotton leaf/dis_leaf (231)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (59)_iaip.jpg',
#  'test/test data comp files/dsd (632)_compressed.jpg',
#  'val/diseased cotton leaf/dis_leaf (57)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (85)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (341)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (12)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (37)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (219)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (61)_iaip.jpg',
#  'test/fresh cotton leaf/d (378).jpg',
#  'val/diseased cotton leaf/dis_leaf (19)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (324)_iaip.jpg',
#  'test/fresh cotton leaf/d (384).jpg',
#  'test/diseased cotton leaf/dis_leaf (322).jpg',
#  'val/diseased cotton leaf/dis_leaf (328)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (78)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (52)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (7)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (93)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (194)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (71)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (242)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (118)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (86)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (323)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (136)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (151)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (149)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (153)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (342)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (17)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (214)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (113)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (44)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (265)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (33)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (260)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (204)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (285)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (235)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (258)_iaip.jpg',
#  'test/diseased cotton plant/dd (706).jpg',
#  'val/diseased cotton leaf/dis_leaf (138)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (287)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (114)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (183)_iaip.jpg',
#  'val/fresh cotton leaf/d (396)_iaip.jpg',
#  'val/fresh cotton leaf/d (458)_iaip.jpg',
#  'val/fresh cotton leaf/d (220)_iaip.jpg',
#  'val/fresh cotton leaf/d (221)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (175)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (309)_iaip.jpg',
#  'val/fresh cotton leaf/d (417)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (253)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (173)_iaip.jpg',
#  'val/fresh cotton leaf/d (192)_iaip.jpg',
#  'val/fresh cotton leaf/d (178)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (100)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (277)_iaip.jpg',
#  'test/diseased cotton plant/dd (328).jpg',
#  'val/diseased cotton leaf/dis_leaf (273)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (296)_iaip.jpg',
#  'val/fresh cotton leaf/d (24)_iaip.jpg',
#  'val/fresh cotton leaf/d (75)_iaip.jpg',
#  'test/diseased cotton plant/dd (41).jpg',
#  'val/fresh cotton leaf/d (416)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (308)_iaip.jpg',
#  'val/fresh cotton leaf/d (38)_iaip.jpg',
#  'val/fresh cotton leaf/d (94)_iaip.jpg',
#  'val/fresh cotton leaf/d (143)_iaip.jpg',
#  'val/fresh cotton leaf/d (76)_iaip.jpg',
#  'val/fresh cotton leaf/d (7)_iaip.jpg',
#  'test/diseased cotton plant/dd (513).jpg',
#  'val/fresh cotton leaf/d (139)_iaip.jpg',
#  'val/fresh cotton leaf/d (433)_iaip.jpg',
#  'val/fresh cotton leaf/d (395)_iaip.jpg',
#  'val/diseased cotton leaf/dis_leaf (298)_iaip.jpg',
#  'val/fresh cotton leaf/d (8)_iaip.jpg',
#  'val/fresh cotton leaf/d (248)_iaip.jpg',
#  'val/fresh cotton leaf/d (117)_iaip.jpg',
#  'val/fresh cotton leaf/d (424)_iaip.jpg',
#  'val/fresh cotton leaf/d (11)_iaip.jpg',
#  'val/fresh cotton leaf/d (229)_iaip.jpg',
#  'val/fresh cotton leaf/d (346)_iaip.jpg',
#  'test/fresh cotton plant/dsd (228).jpg',
#  'val/fresh cotton leaf/d (240)_iaip.jpg',
#  'val/fresh cotton leaf/d (233)_iaip.jpg',
#  'val/fresh cotton leaf/d (197)_iaip.jpg',
#  'val/fresh cotton leaf/d (89)_iaip.jpg',
#  'val/fresh cotton leaf/d (170)_iaip.jpg',
#  'val/fresh cotton leaf/d (193)_iaip.jpg',
#  'val/fresh cotton leaf/d (171)_iaip.jpg',
#  'val/fresh cotton leaf/d (331)_iaip.jpg',
#  'val/fresh cotton leaf/d (67)_iaip.jpg',
#  'val/fresh cotton leaf/d (144)_iaip.jpg',
#  'val/fresh cotton leaf/d (148)_iaip.jpg',
#  'val/fresh cotton leaf/d (26)_iaip.jpg',
#  'val/fresh cotton leaf/d (164)_iaip.jpg',
#  'val/fresh cotton leaf/d (344)_iaip.jpg',
#  'val/fresh cotton leaf/d (308)_iaip.jpg',
#  'val/fresh cotton leaf/d (310)_iaip.jpg',
#  'test/diseased cotton plant/dd (367).jpg',
#  'val/fresh cotton leaf/d (93)_iaip.jpg',
#  'val/fresh cotton leaf/d (301)_iaip.jpg',
#  'val/fresh cotton leaf/d (83)_iaip.jpg',
#  'val/fresh cotton leaf/d (351)_iaip.jpg',
#  'val/fresh cotton leaf/d (306)_iaip.jpg',
#  'val/fresh cotton leaf/d (258)_iaip.jpg',
#  'val/fresh cotton leaf/d (329)_iaip.jpg',
#  'val/fresh cotton leaf/d (61)_iaip.jpg',
#  'val/fresh cotton leaf/d (40)_iaip.jpg',
#  'val/fresh cotton leaf/d (253)_iaip.jpg',
#  'val/fresh cotton leaf/d (255)_iaip.jpg',
#  'val/fresh cotton leaf/d (435)_iaip.jpg',
#  'val/fresh cotton leaf/d (225)_iaip.jpg',
#  'val/fresh cotton leaf/d (9)_iaip.jpg',
#  'val/fresh cotton leaf/d (56)_iaip.jpg',
#  'val/fresh cotton leaf/d (63)_iaip.jpg',
#  'val/fresh cotton leaf/d (283)_iaip.jpg',
#  'val/fresh cotton leaf/d (360)_iaip.jpg',
#  'val/fresh cotton leaf/d (358)_iaip.jpg',
#  'val/fresh cotton leaf/d (112)_iaip.jpg',
#  'val/fresh cotton leaf/d (54)_iaip.jpg',
#  'val/fresh cotton leaf/d (198)_iaip.jpg',
#  'val/fresh cotton leaf/d (122)_iaip.jpg',
#  'val/fresh cotton leaf/d (30)_iaip.jpg',
#  'val/fresh cotton leaf/d (493)_iaip.jpg',
#  'val/fresh cotton leaf/d (359)_iaip.jpg',
#  'val/fresh cotton leaf/d (133)_iaip.jpg',
#  'val/fresh cotton leaf/d (327)_iaip.jpg',
#  'val/fresh cotton leaf/d (350)_iaip.jpg',
#  'val/fresh cotton plant/dsd (362)_iaip.jpg',
#  'val/fresh cotton plant/dsd (327)_iaip.jpg',
#  'val/fresh cotton plant/dsd (313)_iaip.jpg',
#  'val/fresh cotton plant/dsd (293)_iaip.jpg',
#  'val/fresh cotton leaf/d (119)_iaip.jpg',
#  'val/fresh cotton leaf/d (106)_iaip.jpg',
#  'val/fresh cotton leaf/d (291)_iaip.jpg',
#  'val/fresh cotton leaf/d (62)_iaip.jpg',
#  'val/fresh cotton leaf/d (95)_iaip.jpg',
#  'val/fresh cotton plant/dsd (222)_iaip.jpg',
#  'val/fresh cotton plant/dsd (262)_iaip.jpg',
#  'val/fresh cotton leaf/d (299)_iaip.jpg',
#  'val/fresh cotton plant/dsd (245)_iaip.jpg',
#  'val/fresh cotton plant/dsd (292)_iaip.jpg',
#  'val/fresh cotton plant/dsd (450)_iaip.jpg',
#  'val/fresh cotton plant/dsd (443)_iaip.jpg',
#  'val/fresh cotton plant/dsd (300)_iaip.jpg',
#  'val/fresh cotton leaf/d (263)_iaip.jpg',
#  'val/fresh cotton plant/dsd (264)_iaip.jpg',
#  'val/fresh cotton plant/dsd (366)_iaip.jpg',
#  'val/fresh cotton leaf/d (281)_iaip.jpg',
#  'val/fresh cotton plant/dsd (277)_iaip.jpg',
#  'val/fresh cotton plant/dsd (246)_iaip.jpg',
#  'val/fresh cotton plant/dsd (428)_iaip.jpg',
#  'val/fresh cotton plant/dsd (398)_iaip.jpg',
#  'val/fresh cotton leaf/d (282)_iaip.jpg',
#  'val/fresh cotton plant/dsd (378)_iaip.jpg',
#  'val/fresh cotton plant/dsd (190)_iaip.jpg',
#  'val/fresh cotton plant/dsd (420)_iaip.jpg',
#  'val/fresh cotton plant/dsd (168)_iaip.jpg',
#  'val/fresh cotton plant/dsd (461)_iaip.jpg',
#  'val/fresh cotton plant/dsd (167)_iaip.jpg',
#  'val/fresh cotton plant/dsd (593)_iaip.jpg',
#  'val/fresh cotton plant/dsd (329)_iaip.jpg',
#  'val/fresh cotton plant/dsd (176)_iaip.jpg',
#  'val/fresh cotton plant/dsd (465)_iaip.jpg',
#  'val/fresh cotton plant/dsd (435)_iaip.jpg',
#  'val/fresh cotton plant/dsd (221)_iaip.jpg',
#  'val/fresh cotton plant/dsd (396)_iaip.jpg',
#  'val/fresh cotton plant/dsd (621)_iaip.jpg',
#  'val/fresh cotton plant/dsd (337)_iaip.jpg',
#  'val/fresh cotton plant/dsd (496)_iaip.jpg',
#  'val/fresh cotton plant/dsd (205)_iaip.jpg',
#  'val/fresh cotton plant/dsd (361)_iaip.jpg',
#  'val/fresh cotton plant/dsd (400)_iaip.jpg',
#  'val/fresh cotton plant/dsd (195)_iaip.jpg',
#  'val/fresh cotton plant/dsd (601)_iaip.jpg',
#  'val/fresh cotton plant/dsd (409)_iaip.jpg',
#  'val/fresh cotton plant/dsd (180)_iaip.jpg',
#  'val/fresh cotton plant/dsd (341)_iaip.jpg',
#  'val/fresh cotton plant/dsd (342)_iaip.jpg',
#  'val/fresh cotton leaf/d (403)_iaip.jpg',
#  'val/fresh cotton plant/dsd (152)_iaip.jpg',
#  'val/fresh cotton plant/dsd (591)_iaip.jpg',
#  'val/fresh cotton plant/dsd (478)_iaip.jpg',
#  'val/fresh cotton plant/dsd (279)_iaip.jpg',
#  'val/fresh cotton plant/dsd (172)_iaip.jpg',
#  'val/fresh cotton plant/dsd (457)_iaip.jpg',
#  'val/fresh cotton plant/dsd (518)_iaip.jpg',
#  'val/fresh cotton plant/dsd (224)_iaip.jpg',
#  'val/fresh cotton plant/dsd (583)_iaip.jpg',
#  'val/fresh cotton plant/dsd (386)_iaip.jpg',
#  'val/fresh cotton plant/dsd (579)_iaip.jpg',
#  'val/fresh cotton plant/dsd (382)_iaip.jpg',
#  'val/fresh cotton plant/dsd (413)_iaip.jpg',
#  'val/fresh cotton plant/dsd (191)_iaip.jpg',
#  'val/fresh cotton plant/dsd (503)_iaip.jpg',
#  'val/fresh cotton plant/dsd (257)_iaip.jpg',
#  'val/fresh cotton plant/dsd (421)_iaip.jpg',
#  'val/fresh cotton plant/dsd (543)_iaip.jpg',
#  'val/fresh cotton plant/dsd (522)_iaip.jpg',
#  'val/fresh cotton plant/dsd (617)_iaip.jpg',
#  'val/fresh cotton plant/dsd (244)_iaip.jpg',
#  'val/fresh cotton plant/dsd (495)_iaip.jpg',
#  'val/fresh cotton plant/dsd (602)_iaip.jpg',
#  'val/fresh cotton plant/dsd (575)_iaip.jpg',
#  'val/fresh cotton plant/dsd (275)_iaip.jpg',
#  'val/fresh cotton plant/dsd (507)_iaip.jpg',
#  'val/diseased cotton plant/dd (568)_iaip.jpg',
#  'val/fresh cotton plant/dsd (436)_iaip.jpg',
#  'val/fresh cotton plant/dsd (212)_iaip.jpg',
#  'val/fresh cotton plant/dsd (153)_iaip.jpg',
#  'val/fresh cotton plant/dsd (204)_iaip.jpg',
#  'val/fresh cotton plant/dsd (140)_iaip.jpg',
#  'val/fresh cotton plant/dsd (483)_iaip.jpg',
#  'val/fresh cotton plant/dsd (565)_iaip.jpg',
#  'val/fresh cotton plant/dsd (160)_iaip.jpg',
#  'val/fresh cotton plant/dsd (529)_iaip.jpg',
#  'val/diseased cotton plant/dd (559)_iaip.jpg',
#  'val/diseased cotton plant/dd (520)_iaip.jpg',
#  'val/fresh cotton plant/dsd (517)_iaip.jpg',
#  'val/fresh cotton plant/dsd (141)_iaip.jpg',
#  'val/diseased cotton plant/dd (386)_iaip.jpg',
#  'val/diseased cotton plant/dd (500)_iaip.jpg',
#  'val/diseased cotton plant/dd (410)_iaip.jpg',
#  'val/fresh cotton plant/dsd (142)_iaip.jpg',
#  'val/diseased cotton plant/dd (449)_iaip.jpg',
#  'val/diseased cotton plant/dd (476)_iaip.jpg',
#  'val/diseased cotton plant/dd (364)_iaip.jpg',
#  'val/diseased cotton plant/dd (357)_iaip.jpg',
#  'val/diseased cotton plant/dd (548)_iaip.jpg',
#  'val/fresh cotton plant/dsd (533)_iaip.jpg',
#  'val/fresh cotton plant/dsd (558)_iaip.jpg',
#  'val/diseased cotton plant/dd (384)_iaip.jpg',
#  'val/diseased cotton plant/dd (289)_iaip.jpg',
#  'val/diseased cotton plant/dd (353)_iaip.jpg',
#  'val/diseased cotton plant/dd (466)_iaip.jpg',
#  'val/diseased cotton plant/dd (538)_iaip.jpg',
#  'val/fresh cotton plant/dsd (200)_iaip.jpg',
#  'val/fresh cotton plant/dsd (482)_iaip.jpg',
#  'val/fresh cotton plant/dsd (554)_iaip.jpg',
#  'val/diseased cotton plant/dd (268)_iaip.jpg',
#  'val/diseased cotton plant/dd (337)_iaip.jpg',
#  'val/diseased cotton plant/dd (325)_iaip.jpg',
#  'val/diseased cotton plant/dd (261)_iaip.jpg',
#  'val/diseased cotton plant/dd (285)_iaip.jpg',
#  'val/fresh cotton plant/dsd (541)_iaip.jpg',
#  'val/diseased cotton plant/dd (254)_iaip.jpg',
#  'val/fresh cotton plant/dsd (619)_iaip.jpg',
#  'val/diseased cotton plant/dd (488)_iaip.jpg',
#  'val/diseased cotton plant/dd (304)_iaip.jpg',
#  'val/diseased cotton plant/dd (336)_iaip.jpg',
#  'val/diseased cotton plant/dd (456)_iaip.jpg',
#  'val/diseased cotton plant/dd (188)_iaip.jpg',
#  'val/diseased cotton plant/dd (195)_iaip.jpg',
#  'val/fresh cotton plant/dsd (631)_iaip.jpg',
#  'val/diseased cotton plant/dd (115)_iaip.jpg',
#  'val/diseased cotton plant/dd (318)_iaip.jpg',
#  'val/diseased cotton plant/dd (138)_iaip.jpg',
#  'val/diseased cotton plant/dd (111)_iaip.jpg',
#  'train/fresh cotton plant/dsd (376)_iaip.jpg',
#  'train/fresh cotton plant/dsd (235)_iaip.jpg',
#  'val/diseased cotton plant/dd (432)_iaip.jpg',
#  'val/diseased cotton plant/dd (85)_iaip.jpg',
#  'val/diseased cotton plant/dd (314)_iaip.jpg',
#  'val/diseased cotton plant/dd (229)_iaip.jpg',
#  'val/diseased cotton plant/dd (161)_iaip.jpg',
#  'val/diseased cotton plant/dd (216)_iaip.jpg',
#  'val/diseased cotton plant/dd (874)_iaip.jpg',
#  'val/diseased cotton plant/dd (209)_iaip.jpg',
#  'train/fresh cotton plant/dsd (285)_iaip.jpg',
#  'val/diseased cotton plant/dd (862)_iaip.jpg',
#  'val/diseased cotton plant/dd (190)_iaip.jpg',
#  'val/diseased cotton plant/dd (176)_iaip.jpg',
#  'val/diseased cotton plant/dd (299)_iaip.jpg',
#  'val/diseased cotton plant/dd (78)_iaip.jpg',
#  'val/diseased cotton plant/dd (208)_iaip.jpg',
#  'val/diseased cotton plant/dd (233)_iaip.jpg',
#  'val/diseased cotton plant/dd (171)_iaip.jpg',
#  'val/diseased cotton plant/dd (68)_iaip.jpg',
#  'val/diseased cotton plant/dd (175)_iaip.jpg',
#  'val/diseased cotton plant/dd (148)_iaip.jpg',
#  'train/fresh cotton plant/dsd (344)_iaip.jpg',
#  'val/diseased cotton plant/dd (127)_iaip.jpg',
#  'val/diseased cotton plant/dd (240)_iaip.jpg',
#  'val/diseased cotton plant/dd (134)_iaip.jpg',
#  'train/fresh cotton plant/dsd (438)_iaip.jpg',
#  'val/diseased cotton plant/dd (247)_iaip.jpg',
#  'val/diseased cotton plant/dd (70)_iaip.jpg',
#  'val/diseased cotton plant/dd (63)_iaip.jpg',
#  'val/diseased cotton plant/dd (819)_iaip.jpg',
#  'train/fresh cotton plant/dsd (301)_iaip.jpg',
#  'train/fresh cotton plant/dsd (304)_iaip.jpg',
#  'val/diseased cotton plant/dd (879)_iaip.jpg',
#  'train/fresh cotton plant/dsd (169)_iaip.jpg',
#  'val/diseased cotton plant/dd (795)_iaip.jpg',
#  'train/fresh cotton plant/dsd (232)_iaip.jpg',
#  'train/fresh cotton plant/dsd (290)_iaip.jpg',
#  'val/diseased cotton plant/dd (855)_iaip.jpg',
#  'val/diseased cotton plant/dd (40)_iaip.jpg',
#  'train/fresh cotton plant/dsd (226)_iaip.jpg',
#  'train/fresh cotton plant/dsd (170)_iaip.jpg',
#  'train/fresh cotton plant/dsd (177)_iaip.jpg',
#  'train/fresh cotton plant/dsd (286)_iaip.jpg',
#  'train/fresh cotton plant/dsd (434)_iaip.jpg',
#  'train/fresh cotton plant/dsd (271)_iaip.jpg',
#  'train/fresh cotton plant/dsd (314)_iaip.jpg',
#  'train/fresh cotton plant/dsd (215)_iaip.jpg',
#  'val/diseased cotton plant/dd (107)_iaip.jpg',
#  'train/fresh cotton plant/dsd (316)_iaip.jpg',
#  'val/diseased cotton plant/dd (46)_iaip.jpg',
#  'val/diseased cotton plant/dd (825)_iaip.jpg',
#  'val/diseased cotton plant/dd (31)_iaip.jpg',
#  'val/diseased cotton plant/dd (29)_iaip.jpg',
#  'train/fresh cotton plant/dsd (218)_iaip.jpg',
#  'train/fresh cotton plant/dsd (1)_iaip.jpg',
#  'val/diseased cotton plant/dd (842)_iaip.jpg',
#  'val/diseased cotton plant/dd (765)_iaip.jpg',
#  'val/diseased cotton plant/dd (771)_iaip.jpg',
#  'train/fresh cotton plant/dsd (259)_iaip.jpg',
#  'train/fresh cotton plant/dsd (303)_iaip.jpg',
#  'train/fresh cotton plant/dsd (259)_iaip(1).jpg',
#  'val/diseased cotton plant/dd (10)_iaip.jpg',
#  'train/fresh cotton plant/dsd (242)_iaip.jpg',
#  'val/diseased cotton plant/dd (14)_iaip.jpg',
#  'val/diseased cotton plant/dd (21)_iaip.jpg',
#  'val/diseased cotton plant/dd (835)_iaip.jpg',
#  'train/fresh cotton plant/dsd (266)_iaip.jpg',
#  'val/diseased cotton plant/dd (741)_iaip.jpg',
#  'val/diseased cotton plant/dd (731)_iaip.jpg',
#  'val/diseased cotton plant/dd (12)_iaip.jpg',
#  'train/fresh cotton plant/dsd (189)_iaip.jpg',
#  'train/fresh cotton plant/dsd (324)_iaip.jpg',
#  'train/fresh cotton plant/dsd (175)_iaip.jpg',
#  'val/diseased cotton plant/dd (700)_iaip.jpg',
#  'val/diseased cotton plant/dd (721)_iaip.jpg',
#  'val/diseased cotton plant/dd (778)_iaip.jpg',
#  'train/fresh cotton plant/dsd (187)_iaip.jpg',
#  'train/fresh cotton plant/dsd (266)_iaip(1).jpg',
#  'train/fresh cotton plant/dsd (312)_iaip.jpg',
#  'train/fresh cotton plant/dsd (210)_iaip.jpg',
#  'train/fresh cotton plant/dsd (354)_iaip.jpg',
#  'val/diseased cotton plant/dd (676)_iaip.jpg',
#  'train/fresh cotton plant/dsd (332)_iaip.jpg',
#  'val/diseased cotton plant/dd (885)_iaip.jpg',
#  'val/diseased cotton plant/dd (303)_iaip.jpg',
#  'val/diseased cotton plant/dd (901)_iaip.jpg',
#  'train/fresh cotton plant/dsd (263)_iaip(1).jpg',
#  'val/diseased cotton plant/dd (759)_iaip.jpg',
#  'train/fresh cotton plant/dsd (263)_iaip.jpg',
#  'val/diseased cotton plant/dd (618)_iaip.jpg',
#  'val/diseased cotton plant/dd (912)_iaip.jpg',
#  'train/fresh cotton plant/dsd (208)_iaip.jpg',
#  'train/fresh cotton plant/dsd (241)_iaip.jpg',
#  'val/diseased cotton plant/dd (629)_iaip.jpg',
#  'val/diseased cotton plant/dd (893)_iaip.jpg',
#  'train/fresh cotton plant/dsd (182)_iaip.jpg',
#  'train/fresh cotton plant/dsd (288)_iaip.jpg',
#  'val/diseased cotton plant/dd (647)_iaip.jpg',
#  'train/fresh cotton plant/dsd (377)_iaip.jpg',
#  'train/fresh cotton plant/dsd (156)_iaip.jpg',
#  'train/fresh cotton plant/dsd (164)_iaip.jpg',
#  'val/diseased cotton plant/dd (16)_iaip.jpg',
#  'train/fresh cotton plant/dsd (373)_iaip.jpg',
#  'val/diseased cotton plant/dd (711)_iaip.jpg',
#  'train/fresh cotton plant/dsd (179)_iaip.jpg',
#  'val/diseased cotton plant/dd (804)_iaip.jpg',
#  'val/diseased cotton plant/dd (586)_iaip.jpg',
#  'train/fresh cotton plant/dsd (309)_iaip.jpg',
#  'train/fresh cotton plant/dsd (225)_iaip.jpg',
#  'train/fresh cotton plant/dsd (345)_iaip.jpg',
#  'val/diseased cotton plant/dd (637)_iaip.jpg',
#  'train/fresh cotton plant/dsd (230)_iaip.jpg',
#  'train/fresh cotton plant/dsd (343)_iaip.jpg',
#  'train/fresh cotton plant/dsd (280)_iaip.jpg',
#  'train/fresh cotton plant/dsd (363)_iaip.jpg',
#  'val/diseased cotton plant/dd (895)_iaip.jpg',
#  'train/fresh cotton plant/dsd (395)_iaip.jpg',
#  'train/fresh cotton plant/dsd (338)_iaip.jpg',
#  'val/diseased cotton plant/dd (658)_iaip.jpg',
#  'val/diseased cotton plant/dd (687)_iaip.jpg',
#  'train/fresh cotton plant/dsd (294)_iaip.jpg',
#  'train/fresh cotton plant/dsd (248)_iaip.jpg',
#  'train/fresh cotton plant/dsd (213)_iaip.jpg',
#  'train/fresh cotton plant/dsd (185)_iaip.jpg',
#  'train/fresh cotton plant/dsd (403)_iaip.jpg',
#  'train/fresh cotton plant/dsd (317)_iaip.jpg',
#  'train/fresh cotton plant/dsd (525)_iaip.jpg',
#  'val/diseased cotton plant/dd (608)_iaip.jpg',
#  'train/fresh cotton plant/dsd (365)_iaip.jpg',
#  'train/fresh cotton plant/dsd (239)_iaip.jpg',
#  'train/fresh cotton plant/dsd (470)_iaip.jpg',
#  'val/diseased cotton plant/dd (600)_iaip.jpg',
#  'train/fresh cotton plant/dsd (188)_iaip.jpg',
#  'train/fresh cotton plant/dsd (375)_iaip.jpg',
#  'train/fresh cotton plant/dsd (406)_iaip.jpg',
#  'train/fresh cotton plant/dsd (569)_iaip.jpg',
#  'train/fresh cotton plant/dsd (393)_iaip.jpg',
#  'val/diseased cotton plant/dd (579)_iaip.jpg',
#  'train/fresh cotton plant/dsd (562)_iaip.jpg',
#  'train/fresh cotton plant/dsd (561)_iaip.jpg',
#  'train/fresh cotton plant/dsd (492)_iaip.jpg',
#  'train/fresh cotton plant/dsd (545)_iaip.jpg',
#  'train/fresh cotton plant/dsd (209)_iaip.jpg',
#  'train/fresh cotton plant/dsd (523)_iaip.jpg',
#  'train/fresh cotton plant/dsd (474)_iaip.jpg',
#  'train/fresh cotton plant/dsd (526)_iaip.jpg',
#  'train/fresh cotton plant/dsd (348)_iaip.jpg',
#  'train/fresh cotton plant/dsd (352)_iaip.jpg',
#  'train/fresh cotton plant/dsd (439)_iaip.jpg',
#  'train/fresh cotton plant/dsd (427)_iaip.jpg',
#  'train/fresh cotton plant/dsd (506)_iaip.jpg',
#  'train/fresh cotton plant/dsd (364)_iaip.jpg',
#  'train/fresh cotton plant/dsd (480)_iaip.jpg',
#  'train/fresh cotton plant/dsd (186)_iaip.jpg',
#  'train/fresh cotton plant/dsd (493)_iaip.jpg',
#  'train/fresh cotton plant/dsd (328)_iaip.jpg',
#  'train/fresh cotton plant/dsd (560)_iaip.jpg',
#  'train/fresh cotton plant/dsd (463)_iaip.jpg',
#  'train/fresh cotton plant/dsd (512)_iaip.jpg',
#  'train/fresh cotton plant/dsd (410)_iaip.jpg',
#  'train/fresh cotton plant/dsd (571)_iaip.jpg',
#  'train/fresh cotton plant/dsd (243)_iaip.jpg',
#  'train/fresh cotton plant/dsd (383)_iaip.jpg',
#  'train/fresh cotton plant/dsd (402)_iaip.jpg',
#  'train/fresh cotton plant/dsd (422)_iaip.jpg',
#  'train/fresh cotton plant/dsd (437)_iaip.jpg',
#  'train/fresh cotton plant/dsd (536)_iaip.jpg',
#  'train/fresh cotton plant/dsd (603)_iaip.jpg',
#  'train/fresh cotton plant/dsd (311)_iaip.jpg',
#  'train/fresh cotton plant/dsd (508)_iaip.jpg',
#  'train/fresh cotton plant/dsd (407)_iaip.jpg',
#  'train/fresh cotton plant/dsd (196)_iaip.jpg',
#  'train/fresh cotton plant/dsd (369)_iaip.jpg',
#  'train/fresh cotton plant/dsd (433)_iaip.jpg',
#  'train/fresh cotton plant/dsd (162)_iaip.jpg',
#  'train/fresh cotton plant/dsd (588)_iaip.jpg',
#  'train/fresh cotton plant/dsd (430)_iaip.jpg',
#  'train/fresh cotton plant/dsd (563)_iaip.jpg',
#  'train/fresh cotton plant/dsd (201)_iaip.jpg',
#  'train/fresh cotton plant/dsd (227)_iaip.jpg',
#  'train/fresh cotton plant/dsd (416)_iaip.jpg',
#  'train/fresh cotton plant/dsd (161)_iaip.jpg',
#  'train/fresh cotton plant/dsd (389)_iaip.jpg',
#  'train/fresh cotton plant/dsd (197)_iaip.jpg',
#  'train/fresh cotton plant/dsd (296)_iaip.jpg',
#  'train/fresh cotton plant/dsd (385)_iaip.jpg',
#  'train/fresh cotton plant/dsd (346)_iaip.jpg',
#  'train/fresh cotton plant/dsd (399)_iaip.jpg',
#  'train/fresh cotton plant/dsd (289)_iaip.jpg',
#  'train/fresh cotton plant/dsd (166)_iaip.jpg',
#  'train/fresh cotton plant/dsd (379)_iaip.jpg',
#  'train/fresh cotton plant/dsd (173)_iaip.jpg',
#  'train/fresh cotton plant/dsd (335)_iaip.jpg',
#  'train/fresh cotton plant/dsd (163)_iaip.jpg',
#  'train/fresh cotton plant/dsd (391)_iaip.jpg',
#  'train/fresh cotton plant/dsd (451)_iaip.jpg',
#  'train/fresh cotton plant/dsd (158)_iaip.jpg',
#  'train/fresh cotton plant/dsd (231)_iaip.jpg',
#  'train/fresh cotton plant/dsd (184)_iaip.jpg',
#  'train/fresh cotton plant/dsd (511)_iaip.jpg',
#  'train/fresh cotton plant/dsd (334)_iaip.jpg',
#  'train/fresh cotton plant/dsd (181)_iaip.jpg',
#  'train/fresh cotton plant/dsd (384)_iaip.jpg',
#  'train/fresh cotton plant/dsd (326)_iaip.jpg',
#  'train/fresh cotton plant/dsd (157)_iaip.jpg',
#  'train/fresh cotton plant/dsd (320)_iaip.jpg',
#  'train/fresh cotton plant/dsd (171)_iaip.jpg',
#  'train/fresh cotton plant/dsd (276)_iaip.jpg',
#  'train/fresh cotton plant/dsd (521)_iaip.jpg',
#  'train/fresh cotton plant/dsd (555)_iaip.jpg',
#  'train/fresh cotton plant/dsd (616)_iaip.jpg',
#  'train/fresh cotton plant/dsd (350)_iaip.jpg',
#  'train/fresh cotton plant/dsd (198)_iaip.jpg',
#  'train/fresh cotton plant/dsd (302)_iaip.jpg',
#  'train/fresh cotton plant/dsd (339)_iaip.jpg',
#  'train/fresh cotton plant/dsd (477)_iaip.jpg',
#  'train/fresh cotton plant/dsd (458)_iaip.jpg',
#  'train/fresh cotton plant/dsd (520)_iaip.jpg',
#  'train/fresh cotton plant/dsd (165)_iaip.jpg',
#  'train/fresh cotton plant/dsd (308)_iaip.jpg',
#  'train/fresh cotton plant/dsd (623)_iaip.jpg',
#  'train/fresh cotton plant/dsd (446)_iaip.jpg',
#  'train/fresh cotton plant/dsd (497)_iaip.jpg',
#  'train/fresh cotton plant/dsd (321)_iaip.jpg',
#  'train/fresh cotton plant/dsd (476)_iaip.jpg',
#  'train/fresh cotton plant/dsd (392)_iaip.jpg',
#  'train/fresh cotton plant/dsd (444)_iaip.jpg',
#  'train/fresh cotton plant/dsd (596)_iaip.jpg',
#  'train/fresh cotton plant/dsd (633)_iaip.jpg',
#  'train/fresh cotton plant/dsd (333)_iaip.jpg',
#  'train/fresh cotton plant/dsd (564)_iaip.jpg',
#  'train/fresh cotton plant/dsd (622)_iaip.jpg',
#  'train/fresh cotton plant/dsd (484)_iaip.jpg',
#  'train/fresh cotton plant/dsd (620)_iaip.jpg',
#  'train/fresh cotton plant/dsd (250)_iaip.jpg',
#  'train/fresh cotton plant/dsd (618)_iaip.jpg',
#  'train/fresh cotton plant/dsd (530)_iaip.jpg',
#  'train/fresh cotton plant/dsd (548)_iaip.jpg',
#  'train/fresh cotton plant/dsd (261)_iaip(1).jpg',
#  'train/fresh cotton plant/dsd (574)_iaip.jpg',
#  'train/fresh cotton plant/dsd (567)_iaip.jpg',
#  'train/fresh cotton plant/dsd (351)_iaip.jpg',
#  'train/fresh cotton plant/dsd (516)_iaip.jpg',
#  'train/fresh cotton plant/dsd (229)_iaip.jpg',
#  'train/fresh cotton plant/dsd (549)_iaip.jpg',
#  'train/fresh cotton plant/dsd (408)_iaip.jpg',
#  'train/fresh cotton plant/dsd (576)_iaip.jpg',
#  'train/fresh cotton plant/dsd (568)_iaip.jpg',
#  'train/fresh cotton plant/dsd (261)_iaip.jpg',
#  'train/fresh cotton plant/dsd (282)_iaip.jpg',
#  'train/fresh cotton plant/dsd (607)_iaip.jpg',
#  'train/fresh cotton plant/dsd (401)_iaip.jpg',
#  'train/fresh cotton plant/dsd (595)_iaip.jpg',
#  'train/fresh cotton plant/dsd (464)_iaip.jpg',
#  'train/fresh cotton plant/dsd (258)_iaip(1).jpg',
#  'train/fresh cotton plant/dsd (356)_iaip.jpg',
#  'train/fresh cotton plant/dsd (612)_iaip.jpg',
#  'train/fresh cotton plant/dsd (258)_iaip.jpg',
#  'train/fresh cotton plant/dsd (504)_iaip.jpg',
#  'train/fresh cotton plant/dsd (487)_iaip.jpg',
#  'train/fresh cotton plant/dsd (625)_iaip.jpg',
#  'train/fresh cotton plant/dsd (467)_iaip.jpg',
#  'train/fresh cotton plant/dsd (489)_iaip.jpg',
#  'train/fresh cotton plant/dsd (431)_iaip.jpg',
#  'train/fresh cotton plant/dsd (240)_iaip.jpg',
#  'train/fresh cotton plant/dsd (404)_iaip.jpg',
#  'train/fresh cotton plant/dsd (486)_iaip.jpg',
#  'train/fresh cotton plant/dsd (151)_iaip.jpg',
#  'train/fresh cotton plant/dsd (252)_iaip.jpg',
#  'train/fresh cotton plant/dsd (330)_iaip.jpg',
#  'train/fresh cotton plant/dsd (449)_iaip.jpg',
#  'train/fresh cotton plant/dsd (441)_iaip.jpg',
#  'train/fresh cotton plant/dsd (551)_iaip.jpg',
#  'train/fresh cotton plant/dsd (360)_iaip.jpg',
#  'train/fresh cotton plant/dsd (370)_iaip.jpg',
#  'train/fresh cotton plant/dsd (460)_iaip.jpg',
#  'train/fresh cotton plant/dsd (374)_iaip.jpg',
#  'train/fresh cotton plant/dsd (368)_iaip.jpg',
#  'train/fresh cotton plant/dsd (347)_iaip.jpg',
#  'train/fresh cotton plant/dsd (466)_iaip.jpg',
#  'train/fresh cotton plant/dsd (488)_iaip.jpg',
#  'train/fresh cotton plant/dsd (426)_iaip.jpg',
#  'train/fresh cotton plant/dsd (524)_iaip.jpg',
#  'train/fresh cotton plant/dsd (584)_iaip.jpg',
#  'train/fresh cotton plant/dsd (137)_iaip.jpg',
#  'train/fresh cotton plant/dsd (217)_iaip.jpg',
#  'train/fresh cotton plant/dsd (214)_iaip.jpg',
#  'train/fresh cotton plant/dsd (291)_iaip.jpg',
#  'train/fresh cotton plant/dsd (598)_iaip.jpg',
#  'train/fresh cotton plant/dsd (269)_iaip.jpg',
#  'train/fresh cotton plant/dsd (149)_iaip.jpg',
#  'train/fresh cotton plant/dsd (597)_iaip.jpg',
#  'train/fresh cotton plant/dsd (527)_iaip.jpg',
#  'train/fresh cotton plant/dsd (358)_iaip.jpg',
#  'train/fresh cotton plant/dsd (552)_iaip.jpg',
#  'train/fresh cotton plant/dsd (322)_iaip.jpg',
#  'train/fresh cotton plant/dsd (456)_iaip.jpg',
#  'train/fresh cotton plant/dsd (479)_iaip.jpg',
#  'train/fresh cotton plant/dsd (414)_iaip.jpg',
#  'train/fresh cotton plant/dsd (577)_iaip.jpg',
#  'train/fresh cotton plant/dsd (359)_iaip.jpg',
#  'train/fresh cotton plant/dsd (424)_iaip.jpg',
#  'train/fresh cotton plant/dsd (425)_iaip.jpg',
#  'train/diseased cotton plant/dd (564)_iaip.jpg',
#  'train/fresh cotton plant/dsd (501)_iaip.jpg',
#  'train/diseased cotton plant/dd (569)_iaip.jpg',
#  'train/fresh cotton plant/dsd (331)_iaip.jpg',
#  'train/fresh cotton plant/dsd (372)_iaip.jpg',
#  'train/fresh cotton plant/dsd (432)_iaip.jpg',
#  'train/diseased cotton plant/dd (566)_iaip.jpg',
#  'train/diseased cotton plant/dd (553)_iaip.jpg',
#  'train/diseased cotton plant/dd (567)_iaip.jpg',
#  'train/fresh cotton plant/dsd (475)_iaip.jpg',
#  'train/fresh cotton plant/dsd (336)_iaip.jpg',
#  'train/fresh cotton plant/dsd (628)_iaip.jpg',
#  'train/fresh cotton plant/dsd (284)_iaip.jpg',
#  'train/fresh cotton plant/dsd (357)_iaip.jpg',
#  'train/diseased cotton plant/dd (563)_iaip.jpg',
#  'train/diseased cotton plant/dd (547)_iaip.jpg',
#  'train/diseased cotton plant/dd (556)_iaip.jpg',
#  'train/diseased cotton plant/dd (565)_iaip.jpg',
#  'train/fresh cotton plant/dsd (238)_iaip.jpg',
#  'train/diseased cotton plant/dd (550)_iaip.jpg',
#  'train/fresh cotton plant/dsd (481)_iaip.jpg',
#  'train/diseased cotton plant/dd (551)_iaip.jpg',
#  'train/diseased cotton plant/dd (546)_iaip.jpg',
#  'train/diseased cotton plant/dd (545)_iaip.jpg',
#  'train/fresh cotton plant/dsd (371)_iaip.jpg',
#  'train/diseased cotton plant/dd (543)_iaip.jpg',
#  'train/fresh cotton plant/dsd (515)_iaip.jpg',
#  'train/diseased cotton plant/dd (549)_iaip.jpg',
#  'train/diseased cotton plant/dd (542)_iaip.jpg',
#  'train/diseased cotton plant/dd (540)_iaip.jpg',
#  'train/fresh cotton plant/dsd (572)_iaip.jpg',
#  'train/diseased cotton plant/dd (558)_iaip.jpg',
#  'train/diseased cotton plant/dd (560)_iaip.jpg',
#  'train/diseased cotton plant/dd (534)_iaip.jpg',
#  'train/diseased cotton plant/dd (557)_iaip.jpg',
#  'train/diseased cotton plant/dd (561)_iaip.jpg',
#  'train/diseased cotton plant/dd (541)_iaip.jpg',
#  'train/diseased cotton plant/dd (531)_iaip.jpg',
#  'train/fresh cotton plant/dsd (452)_iaip.jpg',
#  'train/diseased cotton plant/dd (555)_iaip.jpg',
#  'train/diseased cotton plant/dd (532)_iaip.jpg',
#  'train/diseased cotton plant/dd (544)_iaip.jpg',
#  'train/diseased cotton plant/dd (570)_iaip.jpg',
#  'train/diseased cotton plant/dd (535)_iaip.jpg',
#  'train/diseased cotton plant/dd (562)_iaip.jpg',
#  'train/diseased cotton plant/dd (524)_iaip.jpg',
#  'train/diseased cotton plant/dd (552)_iaip.jpg',
#  'train/diseased cotton plant/dd (554)_iaip.jpg',
#  'train/diseased cotton plant/dd (533)_iaip.jpg',
#  'train/diseased cotton plant/dd (527)_iaip.jpg',
#  'train/diseased cotton plant/dd (518)_iaip.jpg',
#  'train/diseased cotton plant/dd (516)_iaip.jpg',
#  'train/diseased cotton plant/dd (539)_iaip.jpg',
#  'train/diseased cotton plant/dd (505)_iaip.jpg',
#  'train/diseased cotton plant/dd (536)_iaip.jpg',
#  'train/diseased cotton plant/dd (504)_iaip.jpg',
#  'train/diseased cotton plant/dd (526)_iaip.jpg',
#  'train/diseased cotton plant/dd (508)_iaip.jpg',
#  'train/diseased cotton plant/dd (511)_iaip.jpg',
#  'train/diseased cotton plant/dd (530)_iaip.jpg',
#  'train/diseased cotton plant/dd (523)_iaip.jpg',
#  'train/diseased cotton plant/dd (495)_iaip.jpg',
#  'train/diseased cotton plant/dd (517)_iaip.jpg',
#  'train/diseased cotton plant/dd (497)_iaip.jpg',
#  'train/diseased cotton plant/dd (519)_iaip.jpg',
#  'train/diseased cotton plant/dd (528)_iaip.jpg',
#  'train/diseased cotton plant/dd (493)_iaip.jpg',
#  'train/diseased cotton plant/dd (501)_iaip.jpg',
#  'train/diseased cotton plant/dd (509)_iaip.jpg',
#  'train/diseased cotton plant/dd (529)_iaip.jpg',
#  'train/diseased cotton plant/dd (492)_iaip.jpg',
#  'train/diseased cotton plant/dd (521)_iaip.jpg',
#  'train/diseased cotton plant/dd (499)_iaip.jpg',
#  'train/diseased cotton plant/dd (510)_iaip.jpg',
#  'train/diseased cotton plant/dd (515)_iaip.jpg',
#  'train/diseased cotton plant/dd (498)_iaip.jpg',
#  'train/diseased cotton plant/dd (485)_iaip.jpg',
#  'train/diseased cotton plant/dd (525)_iaip.jpg',
#  'train/diseased cotton plant/dd (496)_iaip.jpg',
#  'train/diseased cotton plant/dd (486)_iaip.jpg',
#  'train/diseased cotton plant/dd (522)_iaip.jpg',
#  'train/diseased cotton plant/dd (502)_iaip.jpg',
#  'train/diseased cotton plant/dd (491)_iaip.jpg',
#  'train/diseased cotton plant/dd (512)_iaip.jpg',
#  'train/diseased cotton plant/dd (507)_iaip.jpg',
#  'train/diseased cotton plant/dd (494)_iaip.jpg',
#  'train/diseased cotton plant/dd (537)_iaip.jpg',
#  'train/diseased cotton plant/dd (472)_iaip.jpg',
#  'train/diseased cotton plant/dd (467)_iaip.jpg',
#  'train/diseased cotton plant/dd (471)_iaip.jpg',
#  'train/diseased cotton plant/dd (465)_iaip.jpg',
#  'train/diseased cotton plant/dd (469)_iaip.jpg',
#  'train/diseased cotton plant/dd (483)_iaip.jpg',
#  'train/diseased cotton plant/dd (514)_iaip.jpg',
#  'train/diseased cotton plant/dd (484)_iaip.jpg',
#  'train/diseased cotton plant/dd (468)_iaip.jpg',
#  'train/diseased cotton plant/dd (503)_iaip.jpg',
#  'train/diseased cotton plant/dd (463)_iaip.jpg',
#  'train/diseased cotton plant/dd (455)_iaip.jpg',
#  'train/diseased cotton plant/dd (454)_iaip.jpg',
#  'train/diseased cotton plant/dd (464)_iaip.jpg',
#  'train/diseased cotton plant/dd (479)_iaip.jpg',
#  'train/diseased cotton plant/dd (477)_iaip.jpg',
#  'train/diseased cotton plant/dd (490)_iaip.jpg',
#  'train/diseased cotton plant/dd (489)_iaip.jpg',
#  'train/diseased cotton plant/dd (481)_iaip.jpg',
#  'train/diseased cotton plant/dd (474)_iaip.jpg',
#  'train/diseased cotton plant/dd (487)_iaip.jpg',
#  'train/diseased cotton plant/dd (448)_iaip.jpg',
#  'train/diseased cotton plant/dd (451)_iaip.jpg',
#  'train/diseased cotton plant/dd (462)_iaip.jpg',
#  'train/diseased cotton plant/dd (438)_iaip.jpg',
#  'train/diseased cotton plant/dd (452)_iaip.jpg',
#  'train/diseased cotton plant/dd (482)_iaip.jpg',
#  'train/diseased cotton plant/dd (446)_iaip.jpg',
#  'train/diseased cotton plant/dd (442)_iaip.jpg',
#  'train/diseased cotton plant/dd (437)_iaip.jpg',
#  'train/diseased cotton plant/dd (480)_iaip.jpg',
#  'train/diseased cotton plant/dd (444)_iaip.jpg',
#  'train/diseased cotton plant/dd (445)_iaip.jpg',
#  'train/diseased cotton plant/dd (458)_iaip.jpg',
#  'train/diseased cotton plant/dd (441)_iaip.jpg',
#  'train/diseased cotton plant/dd (475)_iaip.jpg',
#  'train/diseased cotton plant/dd (439)_iaip.jpg',
#  'train/diseased cotton plant/dd (473)_iaip.jpg',
#  'train/diseased cotton plant/dd (436)_iaip.jpg',
#  'train/diseased cotton plant/dd (478)_iaip.jpg',
#  'train/diseased cotton plant/dd (435)_iaip.jpg',
#  'train/diseased cotton plant/dd (459)_iaip.jpg',
#  'train/diseased cotton plant/dd (434)_iaip.jpg',
#  'train/diseased cotton plant/dd (428)_iaip.jpg',
#  'train/diseased cotton plant/dd (470)_iaip.jpg',
#  'train/diseased cotton plant/dd (426)_iaip.jpg',
#  'train/diseased cotton plant/dd (425)_iaip.jpg',
#  'train/diseased cotton plant/dd (506)_iaip.jpg',
#  'train/diseased cotton plant/dd (461)_iaip.jpg',
#  'train/diseased cotton plant/dd (420)_iaip.jpg',
#  'train/diseased cotton plant/dd (453)_iaip.jpg',
#  'train/diseased cotton plant/dd (431)_iaip.jpg',
#  'train/diseased cotton plant/dd (423)_iaip.jpg',
#  'train/diseased cotton plant/dd (419)_iaip.jpg',
#  'train/diseased cotton plant/dd (421)_iaip.jpg',
#  'train/diseased cotton plant/dd (460)_iaip.jpg',
#  'train/diseased cotton plant/dd (424)_iaip.jpg',
#  'train/diseased cotton plant/dd (447)_iaip.jpg',
#  'train/diseased cotton plant/dd (450)_iaip.jpg',
#  'train/diseased cotton plant/dd (427)_iaip.jpg',
#  'train/diseased cotton plant/dd (440)_iaip.jpg',
#  'train/diseased cotton plant/dd (443)_iaip.jpg',
#  'train/diseased cotton plant/dd (417)_iaip.jpg',
#  'train/diseased cotton plant/dd (409)_iaip.jpg',
#  'train/diseased cotton plant/dd (457)_iaip.jpg',
#  'train/diseased cotton plant/dd (405)_iaip.jpg',
#  'train/diseased cotton plant/dd (413)_iaip.jpg',
#  'train/diseased cotton plant/dd (429)_iaip.jpg',
#  'train/diseased cotton plant/dd (396)_iaip.jpg',
#  'train/diseased cotton plant/dd (402)_iaip.jpg',
#  'train/diseased cotton plant/dd (395)_iaip.jpg',
#  'train/diseased cotton plant/dd (403)_iaip.jpg',
#  'train/diseased cotton plant/dd (416)_iaip.jpg',
#  'train/diseased cotton plant/dd (394)_iaip.jpg',
#  'train/diseased cotton plant/dd (418)_iaip.jpg',
#  'train/diseased cotton plant/dd (392)_iaip.jpg',
#  'train/diseased cotton plant/dd (389)_iaip.jpg',
#  'train/fresh cotton leaf/d (33)_iaip.jpg',
#  'train/diseased cotton plant/dd (390)_iaip.jpg',
#  'train/diseased cotton plant/dd (430)_iaip.jpg',
#  'train/diseased cotton plant/dd (388)_iaip.jpg',
#  'train/diseased cotton plant/dd (385)_iaip.jpg',
#  'train/fresh cotton leaf/d (465)_iaip.jpg',
#  'train/diseased cotton plant/dd (391)_iaip.jpg',
#  'train/diseased cotton plant/dd (415)_iaip.jpg',
#  'train/diseased cotton plant/dd (433)_iaip.jpg',
#  'train/diseased cotton plant/dd (412)_iaip.jpg',
#  'train/diseased cotton plant/dd (406)_iaip.jpg',
#  'train/diseased cotton plant/dd (399)_iaip.jpg',
#  'train/diseased cotton plant/dd (408)_iaip.jpg',
#  'train/fresh cotton leaf/d (391)_iaip.jpg',
#  'train/fresh cotton leaf/d (103)_iaip.jpg',
#  'train/diseased cotton plant/dd (387)_iaip.jpg',
#  'train/diseased cotton plant/dd (404)_iaip.jpg',
#  'train/diseased cotton plant/dd (382)_iaip.jpg',
#  'train/diseased cotton plant/dd (422)_iaip.jpg',
#  'train/diseased cotton plant/dd (400)_iaip.jpg',
#  'train/diseased cotton plant/dd (383)_iaip.jpg',
#  'train/diseased cotton plant/dd (401)_iaip.jpg',
#  'train/diseased cotton plant/dd (398)_iaip.jpg',
#  'train/diseased cotton plant/dd (414)_iaip.jpg',
#  'train/fresh cotton leaf/d (130)_iaip.jpg',
#  'train/diseased cotton plant/dd (407)_iaip.jpg',
#  'train/diseased cotton plant/dd (397)_iaip.jpg',
#  'train/diseased cotton plant/dd (376)_iaip.jpg',
#  'train/diseased cotton plant/dd (377)_iaip.jpg',
#  'train/fresh cotton leaf/d (470)_iaip.jpg',
#  'train/diseased cotton plant/dd (380)_iaip.jpg',
#  'train/diseased cotton plant/dd (373)_iaip.jpg',
#  'train/fresh cotton leaf/d (200)_iaip.jpg',
#  'train/diseased cotton plant/dd (393)_iaip.jpg',
#  'train/fresh cotton leaf/d (101)_iaip.jpg',
#  'train/diseased cotton plant/dd (374)_iaip.jpg',
#  'train/diseased cotton plant/dd (372)_iaip.jpg',
#  'train/diseased cotton plant/dd (366)_iaip.jpg',
#  'train/fresh cotton leaf/d (462)_iaip.jpg',
#  'train/fresh cotton leaf/d (128)_iaip.jpg',
#  'train/diseased cotton plant/dd (368)_iaip.jpg',
#  'train/diseased cotton plant/dd (370)_iaip.jpg',
#  'train/diseased cotton plant/dd (381)_iaip.jpg',
#  'train/diseased cotton plant/dd (378)_iaip.jpg',
#  'train/diseased cotton plant/dd (363)_iaip.jpg',
#  'train/fresh cotton leaf/d (41)_iaip.jpg',
#  'train/diseased cotton plant/dd (365)_iaip.jpg',
#  'train/fresh cotton leaf/d (406)_iaip.jpg',
#  'train/diseased cotton plant/dd (369)_iaip.jpg',
#  'train/diseased cotton plant/dd (360)_iaip.jpg',
#  'train/diseased cotton plant/dd (362)_iaip.jpg',
#  'train/diseased cotton plant/dd (361)_iaip.jpg',
#  'train/fresh cotton leaf/d (387)_iaip.jpg',
#  'train/fresh cotton leaf/d (404)_iaip.jpg',
#  'train/diseased cotton plant/dd (371)_iaip.jpg',
#  'train/fresh cotton leaf/d (142)_iaip.jpg',
#  'train/diseased cotton plant/dd (411)_iaip.jpg',
#  'train/fresh cotton leaf/d (4)_iaip.jpg',
#  'train/fresh cotton leaf/d (463)_iaip.jpg',
#  'train/fresh cotton leaf/d (70)_iaip.jpg',
#  'train/fresh cotton leaf/d (109)_iaip.jpg',
#  'train/fresh cotton leaf/d (21)_iaip.jpg',
#  'train/diseased cotton plant/dd (351)_iaip.jpg',
#  'train/diseased cotton plant/dd (356)_iaip.jpg',
#  'train/fresh cotton leaf/d (383)_iaip.jpg',
#  'train/diseased cotton plant/dd (379)_iaip.jpg',
#  'train/diseased cotton plant/dd (359)_iaip.jpg',
#  'train/diseased cotton plant/dd (352)_iaip.jpg',
#  'train/fresh cotton leaf/d (499)_iaip.jpg',
#  'train/fresh cotton leaf/d (419)_iaip.jpg',
#  'train/fresh cotton leaf/d (64)_iaip.jpg',
#  'train/fresh cotton leaf/d (34)_iaip.jpg',
#  'train/fresh cotton leaf/d (436)_iaip.jpg',
#  'train/fresh cotton leaf/d (382)_iaip.jpg',
#  'train/diseased cotton plant/dd (358)_iaip.jpg',
#  'train/fresh cotton leaf/d (378)_iaip.jpg',
#  'train/diseased cotton plant/dd (355)_iaip.jpg',
#  'train/fresh cotton leaf/d (35)_iaip.jpg',
#  'train/diseased cotton plant/dd (343)_iaip.jpg',
#  'train/diseased cotton plant/dd (346)_iaip.jpg',
#  'train/fresh cotton leaf/d (497)_iaip.jpg',
#  'train/fresh cotton leaf/d (380)_iaip.jpg',
#  'train/fresh cotton leaf/d (74)_iaip.jpg',
#  'train/fresh cotton leaf/d (173)_iaip.jpg',
#  'train/diseased cotton plant/dd (354)_iaip.jpg',
#  'train/diseased cotton plant/dd (375)_iaip.jpg',
#  'train/diseased cotton plant/dd (349)_iaip.jpg',
#  'train/diseased cotton plant/dd (335)_iaip.jpg',
#  'train/diseased cotton plant/dd (342)_iaip.jpg',
#  'train/fresh cotton leaf/d (22)_iaip.jpg',
#  'train/fresh cotton leaf/d (189)_iaip.jpg',
#  'train/diseased cotton plant/dd (347)_iaip.jpg',
#  'train/fresh cotton leaf/d (135)_iaip.jpg',
#  'train/fresh cotton leaf/d (187)_iaip.jpg',
#  'train/diseased cotton plant/dd (339)_iaip.jpg',
#  'train/diseased cotton plant/dd (350)_iaip.jpg',
#  'train/diseased cotton plant/dd (348)_iaip.jpg',
#  'train/diseased cotton plant/dd (344)_iaip.jpg',
#  'train/diseased cotton plant/dd (333)_iaip.jpg',
#  'train/diseased cotton plant/dd (345)_iaip.jpg',
#  'train/fresh cotton leaf/d (505)_iaip.jpg',
#  'train/fresh cotton leaf/d (209)_iaip.jpg',
#  'train/fresh cotton leaf/d (434)_iaip.jpg',
#  'train/fresh cotton leaf/d (477)_iaip.jpg',
#  'train/diseased cotton plant/dd (329)_iaip.jpg',
#  'train/diseased cotton plant/dd (338)_iaip.jpg',
#  'train/fresh cotton leaf/d (466)_iaip.jpg',
#  'train/diseased cotton plant/dd (331)_iaip.jpg',
#  'train/diseased cotton plant/dd (332)_iaip.jpg',
#  'train/fresh cotton leaf/d (498)_iaip.jpg',
#  'train/fresh cotton leaf/d (401)_iaip.jpg',
#  'train/fresh cotton leaf/d (212)_iaip.jpg',
#  'train/fresh cotton leaf/d (3)_iaip.jpg',
#  'train/fresh cotton leaf/d (219)_iaip.jpg',
#  'train/diseased cotton plant/dd (323)_iaip.jpg',
#  'train/fresh cotton leaf/d (379)_iaip.jpg',
#  'train/fresh cotton leaf/d (500)_iaip.jpg',
#  'train/fresh cotton leaf/d (10)_iaip.jpg',
#  'train/fresh cotton leaf/d (503)_iaip.jpg',
#  'train/diseased cotton plant/dd (322)_iaip.jpg',
#  'train/fresh cotton leaf/d (205)_iaip.jpg',
#  'train/diseased cotton plant/dd (313)_iaip.jpg',
#  'train/diseased cotton plant/dd (334)_iaip.jpg',
#  'train/fresh cotton leaf/d (224)_iaip.jpg',
#  'train/fresh cotton leaf/d (85)_iaip.jpg',
#  'train/diseased cotton plant/dd (327)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (80)_iaip.jpg',
#  'train/fresh cotton leaf/d (439)_iaip.jpg',
#  'train/diseased cotton plant/dd (330)_iaip.jpg',
#  'train/fresh cotton leaf/d (236)_iaip.jpg',
#  'train/diseased cotton plant/dd (326)_iaip.jpg',
#  'train/fresh cotton leaf/d (468)_iaip.jpg',
#  'train/diseased cotton plant/dd (324)_iaip.jpg',
#  'train/fresh cotton leaf/d (409)_iaip.jpg',
#  'train/fresh cotton leaf/d (429)_iaip.jpg',
#  'train/diseased cotton plant/dd (311)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (192)_iaip.jpg',
#  'train/fresh cotton leaf/d (167)_iaip.jpg',
#  'train/diseased cotton plant/dd (341)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (69)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (88)_iaip.jpg',
#  'train/diseased cotton plant/dd (307)_iaip.jpg',
#  'train/fresh cotton leaf/d (115)_iaip.jpg',
#  'train/diseased cotton plant/dd (320)_iaip.jpg',
#  'train/diseased cotton plant/dd (315)_iaip.jpg',
#  'train/diseased cotton plant/dd (319)_iaip.jpg',
#  'train/diseased cotton plant/dd (340)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (313)_iaip.jpg',
#  'train/diseased cotton plant/dd (317)_iaip.jpg',
#  'train/diseased cotton plant/dd (321)_iaip.jpg',
#  'train/fresh cotton leaf/d (222)_iaip.jpg',
#  'train/fresh cotton leaf/d (138)_iaip.jpg',
#  'train/diseased cotton plant/dd (308)_iaip.jpg',
#  'train/fresh cotton leaf/d (501)_iaip.jpg',
#  'train/fresh cotton leaf/d (444)_iaip.jpg',
#  'train/diseased cotton plant/dd (316)_iaip.jpg',
#  'train/fresh cotton leaf/d (207)_iaip.jpg',
#  'train/diseased cotton plant/dd (310)_iaip.jpg',
#  'train/diseased cotton plant/dd (309)_iaip.jpg',
#  'train/diseased cotton plant/dd (302)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (236)_iaip.jpg',
#  'train/diseased cotton plant/dd (312)_iaip.jpg',
#  'train/fresh cotton leaf/d (389)_iaip.jpg',
#  'train/fresh cotton leaf/d (459)_iaip.jpg',
#  'train/diseased cotton plant/dd (297)_iaip.jpg',
#  'train/diseased cotton plant/dd (300)_iaip.jpg',
#  'train/diseased cotton plant/dd (301)_iaip.jpg',
#  'train/fresh cotton leaf/d (190)_iaip.jpg',
#  'train/fresh cotton leaf/d (84)_iaip.jpg',
#  'train/diseased cotton plant/dd (295)_iaip.jpg',
#  'train/fresh cotton leaf/d (155)_iaip.jpg',
#  'train/diseased cotton plant/dd (306)_iaip.jpg',
#  'train/fresh cotton leaf/d (482)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (202)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (284)_iaip.jpg',
#  'train/diseased cotton plant/dd (305)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (295)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (221)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (90)_iaip.jpg',
#  'train/fresh cotton leaf/d (397)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (225)_iaip.jpg',
#  'train/fresh cotton leaf/d (415)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (50)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (60)_iaip.jpg',
#  'train/fresh cotton leaf/d (43)_iaip.jpg',
#  'train/diseased cotton plant/dd (294)_iaip.jpg',
#  'train/fresh cotton leaf/d (1)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (56)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (73)_iaip.jpg',
#  'train/fresh cotton leaf/d (402)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (270)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (91)_iaip.jpg',
#  'train/diseased cotton plant/dd (293)_iaip.jpg',
#  'train/fresh cotton leaf/d (399)_iaip.jpg',
#  'train/diseased cotton plant/dd (298)_iaip.jpg',
#  'train/fresh cotton leaf/d (123)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (132)_iaip.jpg',
#  'train/diseased cotton plant/dd (296)_iaip.jpg',
#  'train/fresh cotton leaf/d (107)_iaip.jpg',
#  'train/fresh cotton leaf/d (69)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (79)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (210)_iaip.jpg',
#  'train/fresh cotton leaf/d (437)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (289)_iaip.jpg',
#  'train/fresh cotton leaf/d (202)_iaip.jpg',
#  'train/fresh cotton leaf/d (490)_iaip.jpg',
#  'train/fresh cotton leaf/d (111)_iaip.jpg',
#  'train/fresh cotton leaf/d (461)_iaip.jpg',
#  'train/fresh cotton leaf/d (443)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (172)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (148)_iaip.jpg',
#  'train/fresh cotton leaf/d (390)_iaip.jpg',
#  'train/fresh cotton leaf/d (481)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (40)_iaip.jpg',
#  'train/diseased cotton plant/dd (292)_iaip.jpg',
#  'train/fresh cotton leaf/d (432)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (147)_iaip.jpg',
#  'train/fresh cotton leaf/d (411)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (229)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (321)_iaip.jpg',
#  'train/fresh cotton leaf/d (504)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (189)_iaip.jpg',
#  'train/fresh cotton leaf/d (168)_iaip.jpg',
#  'train/fresh cotton leaf/d (97)_iaip.jpg',
#  'train/fresh cotton leaf/d (471)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (49)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (327)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (82)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (196)_iaip.jpg',
#  'train/fresh cotton leaf/d (65)_iaip.jpg',
#  'train/fresh cotton leaf/d (136)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (162)_iaip.jpg',
#  'train/fresh cotton leaf/d (125)_iaip.jpg',
#  'train/fresh cotton leaf/d (176)_iaip.jpg',
#  'train/fresh cotton leaf/d (46)_iaip.jpg',
#  'train/fresh cotton leaf/d (12)_iaip.jpg',
#  'train/fresh cotton leaf/d (73)_iaip.jpg',
#  'train/fresh cotton leaf/d (175)_iaip.jpg',
#  'train/fresh cotton leaf/d (426)_iaip.jpg',
#  'train/diseased cotton leaf/dis_leaf (139)_iaip.jpg',
#  'train/fresh cotton leaf/d (201)_iaip.jpg',
#  ...]

# %%
def get_updated_list_of_files(list_of_files):
        list = []
        for i in list_of_files:
                dir , file = os.path.split(i)
                if "test data comp files" not in dir :
                        list.append(i)
                else :
                        continue
                
        return list
list1 = get_updated_list_of_files(list)

# %%
bool = True
for i in list1:
    if "test data comp files" in i :
        bool = False

bool
# Out:
# True

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    #data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2024-05-06 15:06:14,730: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-05-06 15:06:14,770: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-05-06 15:06:14,776: INFO: common: created directory at: artifacts]
# [2024-05-06 15:06:14,780: INFO: common: created directory at: artifacts/data_ingestion]

# %%
import os
path = 
os.makedirs()
